# %%
import pandas as pd
import os

# Check working directory
print("Current Path:", os.getcwd())
# Out:
# Current Path: c:\Users\GAURAV SINGH\financial-analytics-project\notebooks

# %%
#LOAD DATA
df = pd.read_excel("data/raw/Online Retail.xlsx")

print("Shape:", df.shape)
df.head()

# %%
#INITIAL CHECKS
df.info()

df.isnull().sum()

df.describe()

# %%
# Remove missing CustomerID
df = df.dropna(subset=['CustomerID'])

print("After removing missing CustomerID:", df.shape)

# %%
# Remove duplicates
df = df.drop_duplicates()

print("After removing duplicates:", df.shape)

# %%
# Remove negative quantity
df = df[df['Quantity'] > 0]

print("After removing negative quantity:", df.shape)

# %%
# Remove invalid prices
df = df[df['UnitPrice'] > 0]

print("After removing invalid prices:", df.shape)

# %%
# Convert Date
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
# Create Revenue
df['Revenue'] = df['Quantity'] * df['UnitPrice']

# %%
# CREATE TIME FEATURES
df['Year'] = df['InvoiceDate'].dt.year
df['Month'] = df['InvoiceDate'].dt.month

# %%
# FINAL VALIDATION
print("Final Shape:", df.shape)

print("\nMissing values:\n", df.isnull().sum())

df.describe()

# %%
# Save cleaned data
df.to_csv("data/cleaned/clean_retail.csv", index=False)

print("Clean data saved successfully")
